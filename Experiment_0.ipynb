# %%
# Name: Rupsa Karak  PRN:25070123098
# Experiment 0

# %%
print("Rupsa Karak")
# Out:
# Rupsa Karak

# %%
print(2)
print(2.5)
print([1,2,5])
print("Rupsa")
# Out:
# 2
# 2.5
# [1, 2, 5]
# Rupsa

# %%
print(2, 2.5, [1,2,5], "Rupsa", sep="\n")
# Out:
# 2
# 2.5
# [1, 2, 5]
# Rupsa

# %%
x= 2
y = 2.5
z =[ 1,2,5]
a = "Rupsa"
print(x,y,z,a)
# Out:
# 2 2.5 [1, 2, 5] Rupsa
